# %%
import pandas as pd

# %%
df = pd.read_csv('pokemon.csv', index_col= 0)

# %%
#df  = df.set_index('#')

# %%
df.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison    318  45      49       49       65
# 2                Ivysaur  Grass  Poison    405  60      62       63       80
# 3               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# 3      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.columns
# Out:
# Index(['Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df[['Name','Type 1']]
# Out:
#                       Name   Type 1
# #
# 1                Bulbasaur    Grass
# 2                  Ivysaur    Grass
# 3                 Venusaur    Grass
# 3    VenusaurMega Venusaur    Grass
# 4               Charmander     Fire
# ..                     ...      ...
# 719                Diancie     Rock
# 719    DiancieMega Diancie     Rock
# 720    HoopaHoopa Confined  Psychic
# 720     HoopaHoopa Unbound  Psychic
# 721              Volcanion     Fire
#
# [800 rows x 2 columns]

# %%
df.iloc[1]
# Out:
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# Total             405
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 2, dtype: object

# %% [markdown]
# loc gets rows (or columns) with particular labels from the index.
#
# iloc gets rows (or columns) at particular positions in the index (so it only takes integers).

# %%
df.iloc[5,3] #specific position
# Out:
# 405

# %%
for index, row in df.iterrows():
    print(index,row)
# Out:
# 1 Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# Total               318
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 1, dtype: object
# 2 Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# Total             405
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 2, dtype: object
# 3 Name          Venusaur
# Type 1           Grass
# Type 2          Poison
# Total              525
# HP                  80
# Attack              82
# Defense             83
# Sp. Atk            100
# Sp. Def            100
# Speed               80
# Generation           1
# Legendary        False
# Name: 3, dtype: object
# ...

# %%
df.loc[df['Type 1'] == 'Fire']
# Out:
#                           Name Type 1    Type 2  Total   HP  Attack  Defense  \
# #
# 4                   Charmander   Fire       NaN    309   39      52       43
# 5                   Charmeleon   Fire       NaN    405   58      64       58
# 6                    Charizard   Fire    Flying    534   78      84       78
# 6    CharizardMega Charizard X   Fire    Dragon    634   78     130      111
# 6    CharizardMega Charizard Y   Fire    Flying    634   78     104       78
# 37                      Vulpix   Fire       NaN    299   38      41       40
# 38                   Ninetales   Fire       NaN    505   73      76       75
# 58                   Growlithe   Fire       NaN    350   55      70       45
# 59                    Arcanine   Fire       NaN    555   90     110       80
# 77                      Ponyta   Fire       NaN    410   50      85       55
# 78                    Rapidash   Fire       NaN    500   65     100       70
# ...

# %%
df.describe()
# Out:
#            Total          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.00000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   435.10250   69.258750   79.001250   73.842500   72.820000   71.902500
# std    119.96304   25.534669   32.457366   31.183501   32.722294   27.828916
# min    180.00000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    330.00000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    450.00000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    515.00000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    780.00000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %% [markdown]
# # sort

# %%
df.sort_values('Name', ascending = False)
# Out:
#                         Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# #
# 718         Zygarde50% Forme   Dragon  Ground    600  108     100      121
# 634                 Zweilous     Dark  Dragon    420   72      85       70
# 41                     Zubat   Poison  Flying    245   40      45       35
# 570                    Zorua     Dark     NaN    330   40      65       40
# 571                  Zoroark     Dark     NaN    510   60     105       60
# ..                       ...      ...     ...    ...  ...     ...      ...
# 359          AbsolMega Absol     Dark     NaN    565   65     150       60
# 359                    Absol     Dark     NaN    465   65     130       60
# 63                      Abra  Psychic     NaN    310   25      20       15
# 460  AbomasnowMega Abomasnow    Grass     Ice    594   90     132      105
# 460                Abomasnow    Grass     Ice    494   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
df.sort_values(['Type 1', 'HP'], ascending = True)
# Out:
#           Name Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 292   Shedinja    Bug   Ghost    236    1      90       45       30       30
# 213    Shuckle    Bug    Rock    505   20      10      230       10      230
# 415     Combee    Bug  Flying    244   30      30       42       30       42
# 543   Venipede    Bug  Poison    260   30      45       59       30       39
# 290    Nincada    Bug  Ground    266   31      45       90       30       30
# ..         ...    ...     ...    ...  ...     ...      ...      ...      ...
# 131     Lapras  Water     Ice    535  130      85       80       85       95
# 134   Vaporeon  Water     NaN    525  130      65       60      110       95
# 320    Wailmer  Water     NaN    400  130      70       35       70       35
# 594  Alomomola  Water     NaN    470  165      75       80       40       45
# 321    Wailord  Water     NaN    500  170      90       45       90       45
#
#      Speed  Generation  Legendary
# #
# ...

# %%
df.sort_values(['Type 1', 'HP'], ascending = [1,0]) #type ascending, hp desc
# Out:
#                         Name Type 1    Type 2  Total  HP  Attack  Defense  \
# #
# 469                  Yanmega    Bug    Flying    515  86      76       86
# 637                Volcarona    Bug      Fire    550  85      60       65
# 214                Heracross    Bug  Fighting    500  80     125       75
# 214  HeracrossMega Heracross    Bug  Fighting    600  80     185      115
# 617                 Accelgor    Bug       NaN    495  80      70       40
# ..                       ...    ...       ...    ...  ..     ...      ...
# 98                    Krabby  Water       NaN    325  30     105       90
# 116                   Horsea  Water       NaN    295  30      40       70
# 120                   Staryu  Water       NaN    340  30      45       55
# 129                 Magikarp  Water       NaN    200  20      10       55
# 349                   Feebas  Water       NaN    200  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %% [markdown]
# # Making changes

# %%
df.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison    318  45      49       49       65
# 2                Ivysaur  Grass  Poison    405  60      62       63       80
# 3               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# 3      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
#making column of total stats

# %%
cols = df.columns.to_list()
df['Total2'] = df[cols[4:10]].sum(axis=1)

# %%
df.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison    318  45      49       49       65
# 2                Ivysaur  Grass  Poison    405  60      62       63       80
# 3               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total2
# #
# 1       65     45           1      False     318
# 2       80     60           1      False     405
# 3      100     80           1      False     525
# 3      120     80           1      False     625
# 4       50     65           1      False     309

# %%
df = df.drop('Total', axis=1)

# %%
df =df.rename(columns = {'Total2':'Total'})

# %%
df = df.drop('Total', axis=1)

# %%
df.head()
# Out:
#                     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison  45      49       49       65
# 2                Ivysaur  Grass  Poison  60      62       63       80
# 3               Venusaur  Grass  Poison  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# 3      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df['Total'] = df.iloc[:,3:9].sum(axis=1) #fastest way to sum

# %%
df.head()
# Out:
#                     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison  45      49       49       65
# 2                Ivysaur  Grass  Poison  60      62       63       80
# 3               Venusaur  Grass  Poison  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# #
# 1       65     45           1      False    318
# 2       80     60           1      False    405
# 3      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
df = df.drop('Total', axis=1)

# %%
df.head()
# Out:
#                     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison  45      49       49       65
# 2                Ivysaur  Grass  Poison  60      62       63       80
# 3               Venusaur  Grass  Poison  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# 3      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# # rearange

# %%
cols = list(df.columns.values)

# %%
print(cols)
# Out:
# ['Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary']

# %%
df.head()
# Out:
#                     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison  45      49       49       65
# 2                Ivysaur  Grass  Poison  60      62       63       80
# 3               Venusaur  Grass  Poison  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# #
# 1       65     45           1      False    318
# 2       80     60           1      False    405
# 3      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %% [markdown]
# # filtering data

# %%
strong_water_pokemons = df.loc[(df['Type 1'] == 'Water') & (df['Total'] > 500)]

# %%
strong_water_pokemons.to_csv('StrngestWater.csv')

# %%
strong_water_pokemons.reset_index(inplace=True, drop=True)

# %%
strong_water_pokemons.head()
# Out:
#                       Name Type 1    Type 2  HP  Attack  Defense  Sp. Atk  \
# 0                Blastoise  Water       NaN  79      83      100       85
# 1  BlastoiseMega Blastoise  Water       NaN  79     103      120      135
# 2                Poliwrath  Water  Fighting  90      95       95       70
# 3               Tentacruel  Water    Poison  80      70       65       80
# 4      SlowbroMega Slowbro  Water   Psychic  95      75      180      130
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0      105     78           1      False    530
# 1      115     78           1      False    630
# 2       90     70           1      False    510
# 3      120    100           1      False    515
# 4       80     30           1      False    590

# %%
strong_water_pokemons.index.name = "#"

# %%
strong_water_pokemons.head()
# Out:
#                       Name Type 1    Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 0                Blastoise  Water       NaN  79      83      100       85
# 1  BlastoiseMega Blastoise  Water       NaN  79     103      120      135
# 2                Poliwrath  Water  Fighting  90      95       95       70
# 3               Tentacruel  Water    Poison  80      70       65       80
# 4      SlowbroMega Slowbro  Water   Psychic  95      75      180      130
#
#    Sp. Def  Speed  Generation  Legendary  Total
# #
# 0      105     78           1      False    530
# 1      115     78           1      False    630
# 2       90     70           1      False    510
# 3      120    100           1      False    515
# 4       80     30           1      False    590

# %%
df.loc[df['Name'].str.contains('Mega')]
# Out:
#                           Name    Type 1    Type 2   HP  Attack  Defense  \
# #
# 3        VenusaurMega Venusaur     Grass    Poison   80     100      123
# 6    CharizardMega Charizard X      Fire    Dragon   78     130      111
# 6    CharizardMega Charizard Y      Fire    Flying   78     104       78
# 9      BlastoiseMega Blastoise     Water       NaN   79     103      120
# 15       BeedrillMega Beedrill       Bug    Poison   65     150       40
# 18         PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 65       AlakazamMega Alakazam   Psychic       NaN   55      50       65
# 80         SlowbroMega Slowbro     Water   Psychic   95      75      180
# 94           GengarMega Gengar     Ghost    Poison   60      65       80
# 115  KangaskhanMega Kangaskhan    Normal       NaN  105     125      100
# 127          PinsirMega Pinsir       Bug    Flying   65     155      120
# 130      GyaradosMega Gyarados     Water      Dark   95     155      109
# ...

# %%
df.loc[~df['Name'].str.contains('Mega')]
# Out:
#                     Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur    Grass  Poison   45      49       49       65
# 2                Ivysaur    Grass  Poison   60      62       63       80
# 3               Venusaur    Grass  Poison   80      82       83      100
# 4             Charmander     Fire     NaN   39      52       43       60
# 5             Charmeleon     Fire     NaN   58      64       58       80
# ..                   ...      ...     ...  ...     ...      ...      ...
# 718     Zygarde50% Forme   Dragon  Ground  108     100      121       81
# 719              Diancie     Rock   Fairy   50     100      150      100
# 720  HoopaHoopa Confined  Psychic   Ghost   80     110       60      150
# 720   HoopaHoopa Unbound  Psychic    Dark   80     160       60      170
# 721            Volcanion     Fire   Water   80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary  Total
# #
# ...

# %% [markdown]
# # regex expression in df

# %%
import re

# %%
df.loc[df['Type 1'].str.contains('fire|water', flags=re.I , regex=True)]
# Out:
#                           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 4                   Charmander   Fire     NaN  39      52       43       60
# 5                   Charmeleon   Fire     NaN  58      64       58       80
# 6                    Charizard   Fire  Flying  78      84       78      109
# 6    CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 6    CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# ..                         ...    ...     ...  ..     ...      ...      ...
# 667                     Litleo   Fire  Normal  62      50       58       73
# 668                     Pyroar   Fire  Normal  86      68       72      109
# 692                  Clauncher  Water     NaN  50      53       62       58
# 693                  Clawitzer  Water     NaN  71      73       88      120
# 721                  Volcanion   Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary  Total
# ...

# %%
#starts with 'pi'
df.loc[df['Name'].str.contains('^pi[a-z]*', flags=re.I , regex=True)]
# Out:
#                     Name    Type 1    Type 2   HP  Attack  Defense  Sp. Atk  \
# #
# 16                Pidgey    Normal    Flying   40      45       40       35
# 17             Pidgeotto    Normal    Flying   63      60       55       50
# 18               Pidgeot    Normal    Flying   83      80       75       70
# 18   PidgeotMega Pidgeot    Normal    Flying   83      80       80      135
# 25               Pikachu  Electric       NaN   35      55       40       50
# 127               Pinsir       Bug       NaN   65     125      100       55
# 127    PinsirMega Pinsir       Bug    Flying   65     155      120       65
# 172                Pichu  Electric       NaN   20      40       15       35
# 204               Pineco       Bug       NaN   50      65       90       35
# 221            Piloswine       Ice    Ground  100     100       80       60
# 393               Piplup     Water       NaN   53      51       53       61
# ...

# %% [markdown]
# # conditional changes

# %%
df = pd.read_csv('StrngestWater.csv', index_col=0)

# %%
df.head()
# Out:
#                        Name Type 1    Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 9                 Blastoise  Water       NaN  79      83      100       85
# 9   BlastoiseMega Blastoise  Water       NaN  79     103      120      135
# 62                Poliwrath  Water  Fighting  90      95       95       70
# 73               Tentacruel  Water    Poison  80      70       65       80
# 80      SlowbroMega Slowbro  Water   Psychic  95      75      180      130
#
#     Sp. Def  Speed  Generation  Legendary  Total
# #
# 9       105     78           1      False    530
# 9       115     78           1      False    630
# 62       90     70           1      False    510
# 73      120    100           1      False    515
# 80       80     30           1      False    590

# %%
df.loc[df['Total'] > 570, ['Generation', 'Legendary']] = ['TEST VALUE 1' , 'TEST VALUE 2']

# %%
df
# Out:
#                         Name Type 1    Type 2   HP  Attack  Defense  Sp. Atk  \
# #
# 9                  Blastoise  Water       NaN   79      83      100       85
# 9    BlastoiseMega Blastoise  Water       NaN   79     103      120      135
# 62                 Poliwrath  Water  Fighting   90      95       95       70
# 73                Tentacruel  Water    Poison   80      70       65       80
# 80       SlowbroMega Slowbro  Water   Psychic   95      75      180      130
# 91                  Cloyster  Water       Ice   50      95      180       85
# 121                  Starmie  Water   Psychic   60      75       85      100
# 130                 Gyarados  Water    Flying   95     125       79       60
# 130    GyaradosMega Gyarados  Water      Dark   95     155      109       70
# 131                   Lapras  Water       Ice  130      85       80       85
# 134                 Vaporeon  Water       NaN  130      65       60      110
# ...

# %%
df = pd.read_csv('Pokemon.csv', index_col=0)

# %%
df
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %% [markdown]
# # GROUP BY

# %%
#group everyone by mean value by types

# %%
df.groupby(['Type 1']).mean()
# Out:
#                Total         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Bug       378.927536  56.884058   70.971014   70.724638  53.869565  64.797101
# Dark      445.741935  66.806452   88.387097   70.225806  74.645161  69.516129
# Dragon    550.531250  83.312500  112.125000   86.375000  96.843750  88.843750
# Electric  443.409091  59.795455   69.090909   66.295455  90.022727  73.704545
# Fairy     413.176471  74.117647   61.529412   65.705882  78.529412  84.705882
# Fighting  416.444444  69.851852   96.777778   65.925926  53.111111  64.703704
# Fire      458.076923  69.903846   84.769231   67.769231  88.980769  72.211538
# Flying    485.000000  70.750000   78.750000   66.250000  94.250000  72.500000
# Ghost     439.562500  64.437500   73.781250   81.187500  79.343750  76.468750
# Grass     421.142857  67.271429   73.214286   70.800000  77.500000  70.428571
# Ground    437.500000  73.781250   95.750000   84.843750  56.468750  62.750000
# ...

# %%
#find one with the best defense

# %%
df.groupby(['Type 1']).mean().sort_values('Defense', ascending=False)
# Out:
#                Total         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Steel     487.703704  65.222222   92.703704  126.370370  67.518519  80.629630
# Rock      453.750000  65.363636   92.863636  100.795455  63.340909  75.477273
# Dragon    550.531250  83.312500  112.125000   86.375000  96.843750  88.843750
# Ground    437.500000  73.781250   95.750000   84.843750  56.468750  62.750000
# Ghost     439.562500  64.437500   73.781250   81.187500  79.343750  76.468750
# Water     430.455357  72.062500   74.151786   72.946429  74.812500  70.517857
# Ice       433.458333  72.000000   72.750000   71.416667  77.541667  76.291667
# Grass     421.142857  67.271429   73.214286   70.800000  77.500000  70.428571
# Bug       378.927536  56.884058   70.971014   70.724638  53.869565  64.797101
# Dark      445.741935  66.806452   88.387097   70.225806  74.645161  69.516129
# Poison    399.142857  67.250000   74.678571   68.821429  60.428571  64.392857
# ...

# %%
df.groupby(['Type 1']).sum()
# Out:
#           Total    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# Type 1
# Bug       26146  3925    4897     4880     3717     4471   4256         222
# Dark      13818  2071    2740     2177     2314     2155   2361         125
# Dragon    17617  2666    3588     2764     3099     2843   2657         124
# Electric  19510  2631    3040     2917     3961     3243   3718         144
# Fairy      7024  1260    1046     1117     1335     1440    826          70
# Fighting  11244  1886    2613     1780     1434     1747   1784          91
# Fire      23820  3635    4408     3524     4627     3755   3871         167
# Flying     1940   283     315      265      377      290    410          22
# Ghost     14066  2062    2361     2598     2539     2447   2059         134
# Grass     29480  4709    5125     4956     5425     4930   4335         235
# Ground    14000  2361    3064     2715     1807     2008   2045         101
# ...

# %%
df.groupby(['Type 1']).sum().sort_values('Attack', ascending=False)
# Out:
#           Total    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# Type 1
# Water     48211  8071    8305     8170     8379     7898   7388         320
# Normal    39365  7573    7200     5865     5470     6245   7012         299
# Grass     29480  4709    5125     4956     5425     4930   4335         235
# Bug       26146  3925    4897     4880     3717     4471   4256         222
# Fire      23820  3635    4408     3524     4627     3755   3871         167
# Rock      19965  2876    4086     4435     2787     3321   2460         152
# Psychic   27129  4026    4073     3858     5609     4918   4645         193
# Dragon    17617  2666    3588     2764     3099     2843   2657         124
# Ground    14000  2361    3064     2715     1807     2008   2045         101
# Electric  19510  2631    3040     2917     3961     3243   3718         144
# Dark      13818  2071    2740     2177     2314     2155   2361         125
# ...

# %%
#df.groupby(['Type 1']).count()

# %%
df['count'] = 1

# %%
df.groupby(['Type 1']).count()['count']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: count, dtype: int64

# %%
df.groupby(['Type 1', 'Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %%
new_df = pd.DataFrame(columns=df.columns)

for df in pd.read_csv('Pokemon.csv', index_col=0, chunksize = 10):
    results = df.groupby(['Type 1']).count()
    
    new_df = pd.concat([new_df, results])
    print(new_df)
# Out:
#       Name Type 1 Type 2 Total HP Attack Defense Sp. Atk Sp. Def Speed  \
# Fire     5    NaN      3     5  5      5       5       5       5     5
# Grass    4    NaN      4     4  4      4       4       4       4     4
# Water    1    NaN      0     1  1      1       1       1       1     1
#
#       Generation Legendary
# Fire           5         5
# Grass          4         4
# Water          1         1
#       Name Type 1 Type 2 Total HP Attack Defense Sp. Atk Sp. Def Speed  \
# Fire     5    NaN      3     5  5      5       5       5       5     5
# Grass    4    NaN      4     4  4      4       4       4       4     4
# Water    1    NaN      0     1  1      1       1       1       1     1
# Bug      7    NaN      5     7  7      7       7       7       7     7
# Water    3    NaN      0     3  3      3       3       3       3     3
#
#       Generation Legendary
# Fire           5         5
# Grass          4         4
# Water          1         1
# ...
